# %%
# Making a Kuzu graph database of webpages/links that Brad is interested in. 
# Visualized with yFiles

# %%
# SECTION 1: DATA CREATION AND LLM CALLS
# --------------------------------------
# This section fetches webpage content, extracts titles, and uses an LLM to categorize and extract keywords,
# producing the final links_with_metadata.csv file for use in the Kùzu database section.

# %%
# All imports

import pandas as pd

from pydantic import BaseModel, Field
import json
from ollama import Client

import requests
from bs4 import BeautifulSoup

import kuzu
import os
from collections import Counter

import warnings

import shutil

# %%
# Cell 1: Generate links.csv with only URLs
import pandas as pd
links_data = [
    {"url": "https://speakerdeck.com/gaelvaroquaux/open-source-software-how-to-live-long-and-go-far"},
    {"url": "https://medium.com/@seanjtaylor/a-personal-retrospective-on-prophet-f223c2378985"},
    {"url": "https://github.com/jackboyla/GLiREL"},
    {"url": "https://www.latencyconf.io/sessions/pandas-should-go-extinct"},
    {"url": "https://orbae.adastra.eco/"},
    {"url": "https://cambridge-intelligence.com/mapweave/"},
    {"url": "https://github.com/yWorks/yfiles-jupyter-graphs-for-sparql"},
    {"url": "https://holonetgalacticmap-frontend.vercel.app/sparql"},
    {"url": "https://arxiv.org/pdf/2502.13025"},
    {"url": "https://medium.com/eqtventures/knowledge-graph-s-and-llm-based-ontologies-have-a-very-good-shot-at-unlocking-genai-in-production-1b167533ef63"},
    {"url": "https://www.mongodb.com/blog/post/supercharge-ai-data-management-knowledge-graphs"},
    {"url": "https://enterprise-knowledge.com/the-resource-description-framework-rdf/"},
    {"url": "https://medium.com/oracledevs/validating-graph-data-with-shacl-using-oracle-rdf-graph-adapter-for-eclipse-rdf4j-09327042f530"},
    {"url": "https://blog.kuzudb.com/post/kuzu-wasm-rag/"},
    {"url": "https://blog.kuzudb.com/post/unstructured-data-to-graph-baml-kuzu/"},
    {"url": "https://medium.com/@mcgeehan/building-a-hybrid-vector-search-database-with-arrow-and-duckdb-07ebc049bc1f"},
    {"url": "https://github.com/Manirevuri/arangodb-hackathon"},
    {"url": "https://medium.com/@tomzeppenfeldt/querying-an-erp-using-an-ai-configuration-in-graphileon-c667f21f5b51"},
    {"url": "https://2024.connected-data.london/speakers/urbashi-mitra/"},
    {"url": "https://darrendevitt.com/all-fhir-concepts-can-be-explained-simply/"},
    {"url": "https://medium.com/@samschifman/rag-on-fhir-with-knowledge-graphs-04d8e13ee96e"},
    {"url": "https://www.sciencedirect.com/science/article/pii/S1532046422002064"},
    {"url": "https://medium.com/enterprise-rag/why-lawyers-are-uniquely-suited-to-work-with-llms-bcc66d3dce98"},
    {"url": "https://link.springer.com/journal/10506"},
    {"url": "https://www.openownership.org/en/blog/lessons-from-building-a-prototype-single-search-tool-for-beneficial-ownership-registers/"},
    {"url": "https://www.occrp.org/en/project/cyprus-confidential/billionaire-roman-abramovichs-company-set-up-fake-superyacht-chartering-scheme-in-apparent-attempt-to-evade-millions-in-taxes"},
    {"url": "https://www.occrp.org/en/project/the-azerbaijani-laundromat/the-contract-factory-inside-danske-bank-estonias-money-laundering-machine"},
    {"url": "https://www.occrp.org/en/project/the-azerbaijani-laundromat/the-raw-data"},
    {"url": "https://discuss.opensanctions.org/"},
    {"url": "https://blog.opencorporates.com/2025/02/13/getting-started-with-the-opencorporates-api/"},
    {"url": "https://www.buzzsprout.com/242645/episodes/16799543"},
    {"url": "https://www.unodc.org/unodc/en/data-and-analysis/tip-studies.html"},
    {"url": "https://www.which.co.uk/news/article/scam-empire-inside-the-275m-fraud-call-centre-operations-aP3Kc4c9HWd7"},
    {"url": "https://www.occrp.org/en/project/scam-empire/scam-operations-relied-on-third-party-marketing-companies-for-steady-stream-of-potential-victims"},
    {"url": "https://github.com/DAD-CDM/dad-cdm-tsc/blob/main/DAD-CDM-Key-Findings-202502.md"},
    {"url": "https://bods-data.openownership.org/source/gleif_version_0_4/"},
    {"url": "https://eiti.org/using-eiti-data"},
    {"url": "https://mweiti.gov.mw/index.php/reports/details/761"},
    {"url": "https://globalenergymonitor.org/projects/global-energy-ownership-tracker/"},
    {"url": "https://www.moodys.com/web/en/us/kyc/resources/insights/how-ai-is-enhancing-ubo-discovery-and-support-reporting-requirements-globally.html"},
    {"url": "https://oecdstatistics.blog/2019/07/04/the-adima-database-on-multinational-enterprises/"},
    {"url": "https://oecdstatistics.blog/2025/02/21/monitoring-multinational-enterprises-how-the-oecd-and-unsd-are-harnessing-open-data/"},
    {"url": "https://www.taxobservatory.eu/publication/the-end-of-londongrad-ownership-transparency-and-offshore-investment-in-real-estate/"},
    {"url": "https://www.future-fis.com/uploads/3/7/9/4/3794525/ffis_a_new_era_of_private_sector_collaboration_to_detect_economic_crime_-_policy_discussion_paper_-_march_2025_-_final.pdf"},
    {"url": "https://www.kharon.com/brief/outbound-investment-rules-china-hong-kong"},
    {"url": "https://www.gao.gov/products/gao-25-107403"},
    {"url": "https://hoeringsportalen.dk/Hearing/Details/69602"},
    {"url": "https://ubm.se/publikationer/publikationer/2025-03-13-kunskapsrapport---avancerade-angrepp-mot-valfardssystemen"},
    {"url": "https://senzing.com/daniel-silva-prudential-senzing-global-user-conference/"},
    {"url": "https://graphaware.com/resources/streamlining-criminal-assets-confiscation/"},
    {"url": "https://graphaware.com/law-enforcement/"},
    {"url": "https://graphaware.com/blog/aml-investigations-detecting-risk-transactions/"},
    {"url": "https://papers.ssrn.com/sol3/papers.cfm?abstract_id=5120765"},
    {"url": "https://www.powermag.com/software-hardware-innovation-all-needed-to-upgrade-the-power-grid/"},
    {"url": "https://wattclarity.com.au/articles/2025/02/nemde-nightmares-parallel-pathways-and-clashing-constraints/"},
    {"url": "https://mahasldc.in/wp-content/reports/other/Report_on_Optimizing_Power_Despatch.pdf"},
    {"url": "https://github.com/kyribaker/7bus_LMPs"},
    {"url": "https://www.ercot.com/content/cdr/html/real_time_system_conditions.html"},
    {"url": "https://www.abc.net.au/news/2024-10-13/australian-coal-plant-in-extraordinary-survival-experiment/104461504"},
    {"url": "https://www.nrdc.org/resources/uneconomic-coal-costs-miso-ratepayers-1-billion-and-curtails-400-mw-wind"},
    {"url": "https://blog.gridstatus.io/curtailment/"},
    {"url": "https://blog.gridstatus.io/spp-expansion-west/"},
    {"url": "https://www.eia.gov/outlooks/steo/"}
]

df = pd.DataFrame(links_data)
csv_path = "links.csv"
df.to_csv(csv_path, index=False)
print(f"CSV saved to {csv_path}")
print(f"Total links: {len(df)}")
# Out:
# CSV saved to links.csv
# Total links: 63

# %%
# Cell 2: Fetch webpage content and extract titles
import pandas as pd
import requests
from bs4 import BeautifulSoup
import warnings

warnings.filterwarnings("ignore")

def fetch_webpage_content(url, retries=2):
    for attempt in range(retries):
        try:
            headers = {'User-Agent': 'Mozilla/5.0'}
            response = requests.get(url, headers=headers, timeout=10)
            response.raise_for_status()
            soup = BeautifulSoup(response.text, 'html.parser')
            text_elements = soup.find_all(['p', 'h1', 'h2', 'h3', 'h4', 'h5', 'h6'])
            text = ' '.join(element.get_text(strip=True) for element in text_elements)
            if len(text) < 100:
                print(f"Insufficient content for {url}: {len(text)} characters")
                return ""
            return text[:5000]
        except Exception as e:
            print(f"Attempt {attempt+1} failed for {url}: {e}")
            if attempt == retries - 1:
                return ""
    return ""

csv_path = "links.csv"
if not os.path.exists(csv_path):
    raise FileNotFoundError(f"{csv_path} not found")
links_df = pd.read_csv(csv_path)

links_df["title"] = ""
links_df["content"] = ""
links_df["category"] = ""
links_df["keyword"] = ""
links_df["category_explanation"] = ""
links_df["keyword_explanation"] = ""

failed_urls = []
for index, row in links_df.iterrows():
    url = row['url']
    print(f"Processing {url} for content and title...")
    content = fetch_webpage_content(url)
    links_df.at[index, 'content'] = content[:5000]
    try:
        soup = BeautifulSoup(requests.get(url, headers={'User-Agent': 'Mozilla/5.0'}).text, 'html.parser')
        title = soup.find('title').text if soup.find('title') else ""
        links_df.at[index, 'title'] = title[:255]
    except:
        links_df.at[index, 'title'] = url
    if not content or len(content.strip()) < 100:
        failed_urls.append({"url": url, "reason": "Failed to fetch sufficient content"})

failed_df = pd.DataFrame(failed_urls)
if not failed_df.empty:
    failed_df.to_csv("links_please_review.csv", index=False)
    print(f"Failed URLs saved to links_please_review.csv: {len(failed_df)} URLs")

links_df = links_df[links_df['content'].str.len() >= 100]
links_df.to_csv("links_with_content.csv", index=False)
print(f"CSV with titles, content, and empty fields saved to links_with_content.csv")
print(f"Processed {len(links_df)} valid URLs")
# Out:
# Processing https://speakerdeck.com/gaelvaroquaux/open-source-software-how-to-live-long-and-go-far for content and title...
# Processing https://medium.com/@seanjtaylor/a-personal-retrospective-on-prophet-f223c2378985 for content and title...
# Processing https://github.com/jackboyla/GLiREL for content and title...
# Processing https://www.latencyconf.io/sessions/pandas-should-go-extinct for content and title...
# Processing https://orbae.adastra.eco/ for content and title...
# Processing https://cambridge-intelligence.com/mapweave/ for content and title...
# Processing https://github.com/yWorks/yfiles-jupyter-graphs-for-sparql for content and title...
# Processing https://holonetgalacticmap-frontend.vercel.app/sparql for content and title...
# Insufficient content for https://holonetgalacticmap-frontend.vercel.app/sparql: 0 characters
# Processing https://arxiv.org/pdf/2502.13025 for content and title...
# Insufficient content for https://arxiv.org/pdf/2502.13025: 0 characters
# Processing https://medium.com/eqtventures/knowledge-graph-s-and-llm-based-ontologies-have-a-very-good-shot-at-unlocking-genai-in-production-1b167533ef63 for content and title...
# Processing https://www.mongodb.com/blog/post/supercharge-ai-data-management-knowledge-graphs for content and title...
# Processing https://enterprise-knowledge.com/the-resource-description-framework-rdf/ for content and title...
# Processing https://medium.com/oracledevs/validating-graph-data-with-shacl-using-oracle-rdf-graph-adapter-for-eclipse-rdf4j-09327042f530 for content and title...
# Processing https://blog.kuzudb.com/post/kuzu-wasm-rag/ for content and title...
# Processing https://blog.kuzudb.com/post/unstructured-data-to-graph-baml-kuzu/ for content and title...
# Processing https://medium.com/@mcgeehan/building-a-hybrid-vector-search-database-with-arrow-and-duckdb-07ebc049bc1f for content and title...
# Processing https://github.com/Manirevuri/arangodb-hackathon for content and title...
# Processing https://medium.com/@tomzeppenfeldt/querying-an-erp-using-an-ai-configuration-in-graphileon-c667f21f5b51 for content and title...
# Processing https://2024.connected-data.london/speakers/urbashi-mitra/ for content and title...
# Processing https://darrendevitt.com/all-fhir-concepts-can-be-explained-simply/ for content and title...
# Processing https://medium.com/@samschifman/rag-on-fhir-with-knowledge-graphs-04d8e13ee96e for content and title...
# Processing https://www.sciencedirect.com/science/article/pii/S1532046422002064 for content and title...
# Attempt 1 failed for https://www.sciencedirect.com/science/article/pii/S1532046422002064: 403 Client Error: Forbidden for url: https://www.sciencedirect.com/science/article/pii/S1532046422002064
# Attempt 2 failed for https://www.sciencedirect.com/science/article/pii/S1532046422002064: 403 Client Error: Forbidden for url: https://www.sciencedirect.com/science/article/pii/S1532046422002064
# Processing https://medium.com/enterprise-rag/why-lawyers-are-uniquely-suited-to-work-with-llms-bcc66d3dce98 for content and title...
# Processing https://link.springer.com/journal/10506 for content and title...
# Processing https://www.openownership.org/en/blog/lessons-from-building-a-prototype-single-search-tool-for-beneficial-ownership-registers/ for content and title...
# Processing https://www.occrp.org/en/project/cyprus-confidential/billionaire-roman-abramovichs-company-set-up-fake-superyacht-chartering-scheme-in-apparent-attempt-to-evade-millions-in-taxes for content and title...
# Processing https://www.occrp.org/en/project/the-azerbaijani-laundromat/the-contract-factory-inside-danske-bank-estonias-money-laundering-machine for content and title...
# Processing https://www.occrp.org/en/project/the-azerbaijani-laundromat/the-raw-data for content and title...
# Processing https://discuss.opensanctions.org/ for content and title...
# Processing https://blog.opencorporates.com/2025/02/13/getting-started-with-the-opencorporates-api/ for content and title...
# Processing https://www.buzzsprout.com/242645/episodes/16799543 for content and title...
# Processing https://www.unodc.org/unodc/en/data-and-analysis/tip-studies.html for content and title...
# Processing https://www.which.co.uk/news/article/scam-empire-inside-the-275m-fraud-call-centre-operations-aP3Kc4c9HWd7 for content and title...
# Processing https://www.occrp.org/en/project/scam-empire/scam-operations-relied-on-third-party-marketing-companies-for-steady-stream-of-potential-victims for content and title...
# Processing https://github.com/DAD-CDM/dad-cdm-tsc/blob/main/DAD-CDM-Key-Findings-202502.md for content and title...
# Processing https://bods-data.openownership.org/source/gleif_version_0_4/ for content and title...
# Processing https://eiti.org/using-eiti-data for content and title...
# Processing https://mweiti.gov.mw/index.php/reports/details/761 for content and title...
# Attempt 1 failed for https://mweiti.gov.mw/index.php/reports/details/761: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
# Processing https://globalenergymonitor.org/projects/global-energy-ownership-tracker/ for content and title...
# Processing https://www.moodys.com/web/en/us/kyc/resources/insights/how-ai-is-enhancing-ubo-discovery-and-support-reporting-requirements-globally.html for content and title...
# Processing https://oecdstatistics.blog/2019/07/04/the-adima-database-on-multinational-enterprises/ for content and title...
# Processing https://oecdstatistics.blog/2025/02/21/monitoring-multinational-enterprises-how-the-oecd-and-unsd-are-harnessing-open-data/ for content and title...
# Processing https://www.taxobservatory.eu/publication/the-end-of-londongrad-ownership-transparency-and-offshore-investment-in-real-estate/ for content and title...
# Processing https://www.future-fis.com/uploads/3/7/9/4/3794525/ffis_a_new_era_of_private_sector_collaboration_to_detect_economic_crime_-_policy_discussion_paper_-_march_2025_-_final.pdf for content and title...
# Insufficient content for https://www.future-fis.com/uploads/3/7/9/4/3794525/ffis_a_new_era_of_private_sector_collaboration_to_detect_economic_crime_-_policy_discussion_paper_-_march_2025_-_final.pdf: 0 characters
# Processing https://www.kharon.com/brief/outbound-investment-rules-china-hong-kong for content and title...
# Processing https://www.gao.gov/products/gao-25-107403 for content and title...
# Processing https://hoeringsportalen.dk/Hearing/Details/69602 for content and title...
# Processing https://ubm.se/publikationer/publikationer/2025-03-13-kunskapsrapport---avancerade-angrepp-mot-valfardssystemen for content and title...
# Processing https://senzing.com/daniel-silva-prudential-senzing-global-user-conference/ for content and title...
# Processing https://graphaware.com/resources/streamlining-criminal-assets-confiscation/ for content and title...
# Processing https://graphaware.com/law-enforcement/ for content and title...
# Processing https://graphaware.com/blog/aml-investigations-detecting-risk-transactions/ for content and title...
# Processing https://papers.ssrn.com/sol3/papers.cfm?abstract_id=5120765 for content and title...
# Processing https://www.powermag.com/software-hardware-innovation-all-needed-to-upgrade-the-power-grid/ for content and title...
# Processing https://wattclarity.com.au/articles/2025/02/nemde-nightmares-parallel-pathways-and-clashing-constraints/ for content and title...
# Processing https://mahasldc.in/wp-content/reports/other/Report_on_Optimizing_Power_Despatch.pdf for content and title...
# Attempt 1 failed for https://mahasldc.in/wp-content/reports/other/Report_on_Optimizing_Power_Despatch.pdf: 403 Client Error: Forbidden for url: https://mahasldc.in/wp-content/reports/other/Report_on_Optimizing_Power_Despatch.pdf
# Attempt 2 failed for https://mahasldc.in/wp-content/reports/other/Report_on_Optimizing_Power_Despatch.pdf: 403 Client Error: Forbidden for url: https://mahasldc.in/wp-content/reports/other/Report_on_Optimizing_Power_Despatch.pdf
# Processing https://github.com/kyribaker/7bus_LMPs for content and title...
# Processing https://www.ercot.com/content/cdr/html/real_time_system_conditions.html for content and title...
# Insufficient content for https://www.ercot.com/content/cdr/html/real_time_system_conditions.html: 0 characters
# Processing https://www.abc.net.au/news/2024-10-13/australian-coal-plant-in-extraordinary-survival-experiment/104461504 for content and title...
# Processing https://www.nrdc.org/resources/uneconomic-coal-costs-miso-ratepayers-1-billion-and-curtails-400-mw-wind for content and title...
# Attempt 1 failed for https://www.nrdc.org/resources/uneconomic-coal-costs-miso-ratepayers-1-billion-and-curtails-400-mw-wind: 403 Client Error: Forbidden for url: https://www.nrdc.org/resources/uneconomic-coal-costs-miso-ratepayers-1-billion-and-curtails-400-mw-wind
# Attempt 2 failed for https://www.nrdc.org/resources/uneconomic-coal-costs-miso-ratepayers-1-billion-and-curtails-400-mw-wind: 403 Client Error: Forbidden for url: https://www.nrdc.org/resources/uneconomic-coal-costs-miso-ratepayers-1-billion-and-curtails-400-mw-wind
# Processing https://blog.gridstatus.io/curtailment/ for content and title...
# Processing https://blog.gridstatus.io/spp-expansion-west/ for content and title...
# Processing https://www.eia.gov/outlooks/steo/ for content and title...
# Attempt 1 failed for https://www.eia.gov/outlooks/steo/: HTTPSConnectionPool(host='www.eia.gov', port=443): Read timed out. (read timeout=10)
# Failed URLs saved to links_please_review.csv: 7 URLs
# CSV with titles, content, and empty fields saved to links_with_content.csv
# Processed 56 valid URLs

# %%
# Cell 3: Categorize and extract one keyword with Ollama using Pydantic
import pandas as pd
from ollama import Client
from pydantic import BaseModel, Field
import json

ollama_client = Client(host='http://localhost:11434')

class ArticleClassification(BaseModel):
    category: str = Field(..., description="The assigned category (2-3 words)", min_length=2, max_length=50)
    keyword: str = Field(..., description="One key term (1-2 words)", min_length=1, max_length=30)
    category_explanation: str = Field(..., description="One sentence explaining the category choice", min_length=10, max_length=200)
    keyword_explanation: str = Field(..., description="One sentence explaining the keyword choice", min_length=10, max_length=200)

suggested_categories = [
    "general tools", "graph technologies", "healthcare data", "ai and legal systems",
    "federated search", "organized crime analysis", "beneficial ownership",
    "financial crime technology", "corporate governance", "power and utilities"
]

def process_with_ollama(content, client, suggested_categories):
    if not content or len(content.strip()) < 100:
        return None
    template = f"""
    You are an expert at categorizing articles and extracting key terms. Analyze the article content and provide a structured JSON output with:
    - "category": A category (2-3 words, from suggested categories: {', '.join(suggested_categories)} or a new one if none fit)
    - "keyword": One key term (1-2 words, specific and descriptive, e.g., 'knowledge graph', not 'data')
    - "category_explanation": One sentence explaining the category choice
    - "keyword_explanation": One sentence explaining the keyword choice
    Return ONLY the JSON object, wrapped in triple backticks (```json\n{{}}\n```).
    Example:
    ```json
    {{
        "category": "graph technologies",
        "keyword": "knowledge graph",
        "category_explanation": "The article discusses graph-based data management.",
        "keyword_explanation": "Knowledge graph is the central concept of the article."
    }}
    ```
    Content: {content[:2000]}
    """
    try:
        response = client.generate(
            model='mistral:7b-instruct-v0.3-q4_0',
            prompt=template,
            options={"temperature": 0.4}
        )
        raw_response = response['response'].strip()
        if raw_response.startswith('```json'):
            raw_response = raw_response[7:].rsplit('```', 1)[0].strip()
        print(f"Raw LLM response for content: {raw_response[:200]}...")
        result = json.loads(raw_response)
        classification = ArticleClassification.model_validate(result)
        return classification
    except Exception as e:
        print(f"Error processing content: {str(e)}")
        return None

links_df = pd.read_csv("links_with_content.csv")
failed_processing = []
for index, row in links_df.iterrows():
    url = row['url']
    print(f"Processing {url} for categorization and keyword...")
    content = row['content']
    result = process_with_ollama(content, ollama_client, suggested_categories)
    if result:
        links_df.at[index, 'category'] = result.category
        links_df.at[index, 'keyword'] = result.keyword
        links_df.at[index, 'category_explanation'] = result.category_explanation
        links_df.at[index, 'keyword_explanation'] = result.keyword_explanation
    else:
        links_df.at[index, 'category'] = "uncategorized"
        links_df.at[index, 'keyword'] = "none"
        links_df.at[index, 'category_explanation'] = "Failed to process content."
        links_df.at[index, 'keyword_explanation'] = "Failed to extract a keyword."
        failed_processing.append({"url": url, "reason": "Failed to generate meaningful category or keyword"})

failed_processing_df = pd.DataFrame(failed_processing)
if not failed_processing_df.empty:
    failed_processing_df.to_csv("failed_processing.csv", index=False)
    print(f"Failed processing saved to failed_processing.csv: {len(failed_processing_df)} URLs")

links_df.to_csv("links_with_metadata.csv", index=False)
print("Updated CSV with titles, content, categories, keywords, and explanations saved to links_with_metadata.csv")
unique_categories = links_df['category'].unique().tolist()
unique_keywords = links_df['keyword'].value_counts()
print(f"Unique categories: {unique_categories}")
print(f"Keyword distribution:\n{unique_keywords}")
# Out:
# Processing https://speakerdeck.com/gaelvaroquaux/open-source-software-how-to-live-long-and-go-far for categorization and keyword...
# Raw LLM response for content: {
#         "category": "general tools",
#         "keyword": "open-source software",
#         "category_explanation": "The article discusses best practices for maintaining open-source software projects.",...
# Processing https://medium.com/@seanjtaylor/a-personal-retrospective-on-prophet-f223c2378985 for categorization and keyword...
# Raw LLM response for content: {
#         "category": "ai and legal systems",
#         "keyword": "Prophet",
#         "category_explanation": "The article discusses an AI-based forecasting library called Prophet.",
#         "keyword_ex...
# Processing https://github.com/jackboyla/GLiREL for categorization and keyword...
# Raw LLM response for content: {
#         "category": "ai",
#         "keyword": "relation extraction",
#         "category_explanation": "The article discusses an AI model for relation extraction.",
#         "keyword_explanation": "Rela...
# Processing https://www.latencyconf.io/sessions/pandas-should-go-extinct for categorization and keyword...
# Raw LLM response for content: {
#         "category": "general tools",
#         "keyword": "in-memory analytics",
#         "category_explanation": "The article discusses a tool for in-memory data analysis, which is not specific to a p...
# Processing https://orbae.adastra.eco/ for categorization and keyword...
# Raw LLM response for content: {
#         "category": "environmental sustainability",
#         "keyword": "land conversion",
#         "category_explanation": "The article discusses the impacts of land conversion, particularly in agric...
# Processing https://cambridge-intelligence.com/mapweave/ for categorization and keyword...
# Raw LLM response for content: {
#         "category": "organized crime analysis",
#         "keyword": "MapWeave",
#         "category_explanation": "The article discusses a tool used for geospatial visualization, which is often applied...
# Processing https://github.com/yWorks/yfiles-jupyter-graphs-for-sparql for categorization and keyword...
# Raw LLM response for content: {
#         "category": "graph technologies",
#         "keyword": "SparQL Graph Widget",
#         "category_explanation": "The article discusses a tool for visualizing SPARQL queries in Jupyter Notebooks,...
# Processing https://medium.com/eqtventures/knowledge-graph-s-and-llm-based-ontologies-have-a-very-good-shot-at-unlocking-genai-in-production-1b167533ef63 for categorization and keyword...
# Raw LLM response for content: {
#         "category": "graph technologies",
#         "keyword": "knowledge graph",
#         "category_explanation": "The article discusses the role and potential of knowledge graphs in improving AI mode...
# Processing https://www.mongodb.com/blog/post/supercharge-ai-data-management-knowledge-graphs for categorization and keyword...
# Raw LLM response for content: {
#         "category": "ai and legal systems",
#         "keyword": "knowledge graph",
#         "category_explanation": "The article discusses the use of AI, specifically knowledge graphs, in the context ...
# Processing https://enterprise-knowledge.com/the-resource-description-framework-rdf/ for categorization and keyword...
# Raw LLM response for content: {
#         "category": "graph technologies",
#         "keyword": "RDF",
#         "category_explanation": "The article discusses graph-based data representation using RDF, a popular and ubiquitous standar...
# Processing https://medium.com/oracledevs/validating-graph-data-with-shacl-using-oracle-rdf-graph-adapter-for-eclipse-rdf4j-09327042f530 for categorization and keyword...
# Raw LLM response for content: {
#         "category": "graph technologies",
#         "keyword": "SHACL validation",
#         "category_explanation": "The article discusses the use of SHACL for validating graph data in Oracle RDF Graph...
# Processing https://blog.kuzudb.com/post/kuzu-wasm-rag/ for categorization and keyword...
# Raw LLM response for content: {
#         "category": "graph technologies",
#         "keyword": "Graph RAG",
#         "category_explanation": "The article discusses the use of a graph-based data management technique called Graph Retri...
# Processing https://blog.kuzudb.com/post/unstructured-data-to-graph-baml-kuzu/ for categorization and keyword...
# Raw LLM response for content: {
#         "category": "healthcare data",
#         "keyword": "clinical notes",
#         "category_explanation": "The article discusses the use of unstructured healthcare data for analysis.",
#         "ke...
# Processing https://medium.com/@mcgeehan/building-a-hybrid-vector-search-database-with-arrow-and-duckdb-07ebc049bc1f for categorization and keyword...
# Raw LLM response for content: {
#         "category": "federated search",
#         "keyword": "hybrid vector database",
#         "category_explanation": "The article discusses a hybrid system that combines fast vector search with SQL-...
# Processing https://github.com/Manirevuri/arangodb-hackathon for categorization and keyword...
# Raw LLM response for content: {
#         "category": "ai and legal systems",
#         "keyword": "CVE graph database",
#         "category_explanation": "The article discusses the development of an AI agent for processing natural lang...
# Error processing content: 1 validation error for ArticleClassification
# category_explanation
#   String should have at most 200 characters [type=string_too_long, input_value='The article discusses th...l and security systems.', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_too_long
# Processing https://medium.com/@tomzeppenfeldt/querying-an-erp-using-an-ai-configuration-in-graphileon-c667f21f5b51 for categorization and keyword...
# Raw LLM response for content: {
#         "category": "ai and legal systems",
#         "keyword": "AI configuration",
#         "category_explanation": "The article discusses the use of AI in configuring a system for querying data.",
#  ...
# Processing https://2024.connected-data.london/speakers/urbashi-mitra/ for categorization and keyword...
# Raw LLM response for content: {
#         "category": "ai and legal systems",
#         "keyword": "IEEE Information Theory Society’s Aaron D. Wyner Distinguished Service Award",
#         "category_explanation": "The article discusses ...
# Error processing content: 1 validation error for ArticleClassification
# keyword
#   String should have at most 30 characters [type=string_too_long, input_value='IEEE Information Theory ...inguished Service Award', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_too_long
# Processing https://darrendevitt.com/all-fhir-concepts-can-be-explained-simply/ for categorization and keyword...
# Raw LLM response for content: {
#         "category": "healthcare data",
#         "keyword": "FHIR",
#         "category_explanation": "The article discusses FHIR, a standard for exchanging electronic health records.",
#         "keyword...
# Processing https://medium.com/@samschifman/rag-on-fhir-with-knowledge-graphs-04d8e13ee96e for categorization and keyword...
# Raw LLM response for content: {
#         "category": "healthcare data",
#         "keyword": "FHIR",
#         "category_explanation": "The article discusses the use of Fast Healthcare Interoperable Resources (FHIR) in healthcare data ...
# Processing https://medium.com/enterprise-rag/why-lawyers-are-uniquely-suited-to-work-with-llms-bcc66d3dce98 for categorization and keyword...
# Raw LLM response for content: {
#         "category": "ai and legal systems",
#         "keyword": "Retrieval Augmented Generation (RAG)",
#         "category_explanation": "The article discusses the collaboration between lawyers and AI...
# Error processing content: 1 validation error for ArticleClassification
# keyword
#   String should have at most 30 characters [type=string_too_long, input_value='Retrieval Augmented Generation (RAG)', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_too_long
# Processing https://link.springer.com/journal/10506 for categorization and keyword...
# Raw LLM response for content: {
#         "category": "ai and legal systems",
#         "keyword": "artificial intelligence",
#         "category_explanation": "The article focuses on the application of artificial intelligence in the le...
# Processing https://www.openownership.org/en/blog/lessons-from-building-a-prototype-single-search-tool-for-beneficial-ownership-registers/ for categorization and keyword...
# Raw LLM response for content: {
#         "category": "federated search",
#         "keyword": "multi-country BO search tool",
#         "category_explanation": "The article discusses the development and testing of a tool to search bene...
# Processing https://www.occrp.org/en/project/cyprus-confidential/billionaire-roman-abramovichs-company-set-up-fake-superyacht-chartering-scheme-in-apparent-attempt-to-evade-millions-in-taxes for categorization and keyword...
# Raw LLM response for content: {
#         "category": "financial crime technology",
#         "keyword": "tax evasion",
#         "category_explanation": "The article discusses a financial crime involving the attempt to evade taxes.",
#  ...
# Processing https://www.occrp.org/en/project/the-azerbaijani-laundromat/the-contract-factory-inside-danske-bank-estonias-money-laundering-machine for categorization and keyword...
# Raw LLM response for content: {
#         "category": "financial crime technology",
#         "keyword": "money laundering",
#         "category_explanation": "The article discusses a case of money laundering involving multiple individu...
# Processing https://www.occrp.org/en/project/the-azerbaijani-laundromat/the-raw-data for categorization and keyword...
# Raw LLM response for content: {
#         "category": "organized crime analysis",
#         "keyword": "Azerbaijani Laundromat",
#         "category_explanation": "The article discusses an investigation into a money laundering scheme, s...
# Processing https://discuss.opensanctions.org/ for categorization and keyword...
# Raw LLM response for content: {
#         "category": "financial crime technology",
#         "keyword": "OpenSanctions",
#         "category_explanation": "The article discusses a database and API related to financial crimes.",
#        ...
# Processing https://blog.opencorporates.com/2025/02/13/getting-started-with-the-opencorporates-api/ for categorization and keyword...
# Raw LLM response for content: {
#         "category": "financial crime technology",
#         "keyword": "OpenCorporates API",
#         "category_explanation": "The article discusses a tool used for accessing company data, which is oft...
# Processing https://www.buzzsprout.com/242645/episodes/16799543 for categorization and keyword...
# Raw LLM response for content: {
#         "category": "organized crime analysis",
#         "keyword": "suspicious activity reports (SARs)",
#         "category_explanation": "The article discusses the analysis of suspicious activities,...
# Error processing content: 1 validation error for ArticleClassification
# keyword
#   String should have at most 30 characters [type=string_too_long, input_value='suspicious activity reports (SARs)', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_too_long
# Processing https://www.unodc.org/unodc/en/data-and-analysis/tip-studies.html for categorization and keyword...
# Raw LLM response for content: {
#         "category": "organized crime analysis",
#         "keyword": "trafficking in persons",
#         "category_explanation": "The article discusses a study on organized crimes, specifically traffick...
# Processing https://www.which.co.uk/news/article/scam-empire-inside-the-275m-fraud-call-centre-operations-aP3Kc4c9HWd7 for categorization and keyword...
# Raw LLM response for content: {
#         "category": "organized crime analysis",
#         "keyword": "Scam Empire",
#         "category_explanation": "The article discusses an investigation into a large-scale investment scam, which fa...
# Processing https://www.occrp.org/en/project/scam-empire/scam-operations-relied-on-third-party-marketing-companies-for-steady-stream-of-potential-victims for categorization and keyword...
# Raw LLM response for content: {
#         "category": "organized crime analysis",
#         "keyword": "scam operation",
#         "category_explanation": "The article discusses an illegal activity carried out by organized groups, in th...
# Processing https://github.com/DAD-CDM/dad-cdm-tsc/blob/main/DAD-CDM-Key-Findings-202502.md for categorization and keyword...
# Raw LLM response for content: {
#         "category": "general tools",
#         "keyword": "search code",
#         "category_explanation": "The article discusses a tool related to searching and filtering data.",
#         "keyword_expla...
# Processing https://bods-data.openownership.org/source/gleif_version_0_4/ for categorization and keyword...
# Raw LLM response for content: {
#         "category": "beneficial ownership",
#         "keyword": "Beneficial Ownership Data Standard",
#         "category_explanation": "The article discusses the analysis of beneficial ownership data,...
# Error processing content: 1 validation error for ArticleClassification
# keyword
#   String should have at most 30 characters [type=string_too_long, input_value='Beneficial Ownership Data Standard', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_too_long
# Processing https://eiti.org/using-eiti-data for categorization and keyword...
# Raw LLM response for content: {
#         "category": "federated search",
#         "keyword": "EITI data",
#         "category_explanation": "The article discusses the use of EITI data for federated search across various sectors to add...
# Processing https://mweiti.gov.mw/index.php/reports/details/761 for categorization and keyword...
# Raw LLM response for content: {
#         "category": "federated search",
#         "keyword": "beneficial ownership disclosure",
#         "category_explanation": "The article discusses the accessibility and implementation of beneficia...
# Error processing content: 1 validation error for ArticleClassification
# keyword
#   String should have at most 30 characters [type=string_too_long, input_value='beneficial ownership disclosure', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_too_long
# Processing https://globalenergymonitor.org/projects/global-energy-ownership-tracker/ for categorization and keyword...
# Raw LLM response for content: {
#         "category": "financial crime technology",
#         "keyword": "Global Energy Ownership Tracker",
#         "category_explanation": "The article discusses a tool used to track ownership of energ...
# Error processing content: 1 validation error for ArticleClassification
# keyword
#   String should have at most 30 characters [type=string_too_long, input_value='Global Energy Ownership Tracker', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_too_long
# Processing https://www.moodys.com/web/en/us/kyc/resources/insights/how-ai-is-enhancing-ubo-discovery-and-support-reporting-requirements-globally.html for categorization and keyword...
# Raw LLM response for content: {
#         "category": "financial crime technology",
#         "keyword": "AI algorithms",
#         "category_explanation": "The article discusses the use of AI in detecting and preventing financial crime...
# Processing https://oecdstatistics.blog/2019/07/04/the-adima-database-on-multinational-enterprises/ for categorization and keyword...
# Raw LLM response for content: {
#         "category": "financial crime technology",
#         "keyword": "Effective Tax Rate (ETR)",
#         "category_explanation": "The article discusses a database that provides insights into the fin...
# Processing https://oecdstatistics.blog/2025/02/21/monitoring-multinational-enterprises-how-the-oecd-and-unsd-are-harnessing-open-data/ for categorization and keyword...
# Raw LLM response for content: {
#         "category": "financial crime technology",
#         "keyword": "Multinational Enterprise Information Platform (MEIP)",
#         "category_explanation": "The article discusses a technology platf...
# Error processing content: 1 validation error for ArticleClassification
# keyword
#   String should have at most 30 characters [type=string_too_long, input_value='Multinational Enterprise...rmation Platform (MEIP)', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_too_long
# Processing https://www.taxobservatory.eu/publication/the-end-of-londongrad-ownership-transparency-and-offshore-investment-in-real-estate/ for categorization and keyword...
# Raw LLM response for content: {
#         "category": "financial crime technology",
#         "keyword": "beneficial ownership transparency",
#         "category_explanation": "The article discusses a financial crime-related topic: bene...
# Error processing content: 1 validation error for ArticleClassification
# keyword
#   String should have at most 30 characters [type=string_too_long, input_value='beneficial ownership transparency', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_too_long
# Processing https://www.kharon.com/brief/outbound-investment-rules-china-hong-kong for categorization and keyword...
# Raw LLM response for content: {
#         "category": "legal systems",
#         "keyword": "patents",
#         "category_explanation": "The article discusses legal aspects such as patents.",
#         "keyword_explanation": "Patents are...
# Processing https://www.gao.gov/products/gao-25-107403 for categorization and keyword...
# Raw LLM response for content: {
#         "category": "financial crime technology",
#         "keyword": "beneficial ownership",
#         "category_explanation": "The article discusses the use of beneficial ownership information in fin...
# Processing https://hoeringsportalen.dk/Hearing/Details/69602 for categorization and keyword...
# Raw LLM response for content: {
#         "category": "legal systems",
#         "keyword": "real owners",
#         "category_explanation": "The article is about a proposal for a law change regarding business register, companies' law, ...
# Processing https://ubm.se/publikationer/publikationer/2025-03-13-kunskapsrapport---avancerade-angrepp-mot-valfardssystemen for categorization and keyword...
# Raw LLM response for content: {
#         "category": "organized crime analysis",
#         "keyword": "identity fraud",
#         "category_explanation": "The article discusses advanced attacks on welfare systems, with a focus on organ...
# Processing https://senzing.com/daniel-silva-prudential-senzing-global-user-conference/ for categorization and keyword...
# Raw LLM response for content: {
#         "category": "financial crime technology",
#         "keyword": "fraud detection",
#         "category_explanation": "The article discusses the use of advanced technologies for detecting insuranc...
# Processing https://graphaware.com/resources/streamlining-criminal-assets-confiscation/ for categorization and keyword...
# Raw LLM response for content: {
#         "category": "organized crime analysis",
#         "keyword": "graph technology",
#         "category_explanation": "The article discusses the use of graph technology in organized crime analysis ...
# Processing https://graphaware.com/law-enforcement/ for categorization and keyword...
# Raw LLM response for content: {
#         "category": "organized crime analysis",
#         "keyword": "connected data analytics",
#         "category_explanation": "The article focuses on using connected data analytics for organized cr...
# Processing https://graphaware.com/blog/aml-investigations-detecting-risk-transactions/ for categorization and keyword...
# Raw LLM response for content: {
#         "category": "financial crime technology",
#         "keyword": "network analytics",
#         "category_explanation": "The article discusses the use of network analytics in Anti-Money Laundering...
# Processing https://papers.ssrn.com/sol3/papers.cfm?abstract_id=5120765 for categorization and keyword...
# Raw LLM response for content: {
#         "category": "corporate governance",
#         "keyword": "shareholder primacy",
#         "category_explanation": "The article discusses the principles and practices of corporate governance, spe...
# Processing https://www.powermag.com/software-hardware-innovation-all-needed-to-upgrade-the-power-grid/ for categorization and keyword...
# Raw LLM response for content: {
#         "category": "power and utilities",
#         "keyword": "grid enhancement",
#         "category_explanation": "The article focuses on the power and utility sector, specifically discussing improv...
# Processing https://wattclarity.com.au/articles/2025/02/nemde-nightmares-parallel-pathways-and-clashing-constraints/ for categorization and keyword...
# Raw LLM response for content: {
#         "category": "federated search",
#         "keyword": "NEMDE",
#         "category_explanation": "The article discusses a federated data system (NEM) and the challenges of searching across it.",
# ...
# Processing https://github.com/kyribaker/7bus_LMPs for categorization and keyword...
# Raw LLM response for content: {
#         "category": "power and utilities",
#         "keyword": "locational marginal prices (LMP)",
#         "category_explanation": "The article discusses a power grid system, focusing on locational m...
# Error processing content: 1 validation error for ArticleClassification
# keyword
#   String should have at most 30 characters [type=string_too_long, input_value='locational marginal prices (LMP)', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_too_long
# Processing https://www.abc.net.au/news/2024-10-13/australian-coal-plant-in-extraordinary-survival-experiment/104461504 for categorization and keyword...
# Raw LLM response for content: {
#         "category": "power and utilities",
#         "keyword": "two-shifting",
#         "category_explanation": "The article discusses the operation of a coal power plant, which is a key aspect of the...
# Processing https://blog.gridstatus.io/curtailment/ for categorization and keyword...
# Raw LLM response for content: {
#         "category": "power and utilities",
#         "keyword": "curtailment",
#         "category_explanation": "The article discusses the concept of curtailment in power grid operations, specifically ...
# Processing https://blog.gridstatus.io/spp-expansion-west/ for categorization and keyword...
# Raw LLM response for content: {
#         "category": "power and utilities",
#         "keyword": "RTO/ISO expansion",
#         "category_explanation": "The article discusses the expansion of an organized electricity market (RTO/ISO) w...
# Processing https://www.eia.gov/outlooks/steo/ for categorization and keyword...
# Raw LLM response for content: {
#         "category": "power and utilities",
#         "keyword": "energy information",
#         "category_explanation": "The article is about statistics and analysis related to power and utilities, incl...
# Failed processing saved to failed_processing.csv: 10 URLs
# Updated CSV with titles, content, categories, keywords, and explanations saved to links_with_metadata.csv
# Unique categories: ['general tools', 'ai and legal systems', 'ai', 'environmental sustainability', 'organized crime analysis', 'graph technologies', 'healthcare data', 'federated search', 'uncategorized', 'financial crime technology', 'legal systems', 'corporate governance', 'power and utilities']
# Keyword distribution:
# keyword
# none                            10
# FHIR                             2
# knowledge graph                  2
# Prophet                          1
# relation extraction              1
# land conversion                  1
# MapWeave                         1
# SparQL Graph Widget              1
# RDF                              1
# SHACL validation                 1
# Graph RAG                        1
# in-memory analytics              1
# open-source software             1
# hybrid vector database           1
# clinical notes                   1
# AI configuration                 1
# artificial intelligence          1
# multi-country BO search tool     1
# tax evasion                      1
# money laundering                 1
# Azerbaijani Laundromat           1
# OpenSanctions                    1
# OpenCorporates API               1
# trafficking in persons           1
# Scam Empire                      1
# scam operation                   1
# search code                      1
# EITI data                        1
# AI algorithms                    1
# Effective Tax Rate (ETR)         1
# patents                          1
# beneficial ownership             1
# real owners                      1
# identity fraud                   1
# fraud detection                  1
# graph technology                 1
# connected data analytics         1
# network analytics                1
# shareholder primacy              1
# grid enhancement                 1
# NEMDE                            1
# two-shifting                     1
# curtailment                      1
# RTO/ISO expansion                1
# energy information               1
# Name: count, dtype: int64

# %%
links_df.sample(5)
# Out:
#                                                   url  \
# 45  https://graphaware.com/resources/streamlining-...
# 38  https://oecdstatistics.blog/2025/02/21/monitor...
# 18  https://medium.com/@samschifman/rag-on-fhir-wi...
# 29  https://www.which.co.uk/news/article/scam-empi...
# 16  https://2024.connected-data.london/speakers/ur...
#
#                                                 title  \
# 45  Streamlining Criminal Assets Confiscation | Gr...
# 38  Monitoring multinational enterprises: How the ...
# 18  RAG on FHIR with Knowledge Graphs | by Sam Sch...
# 29  Scam Empire: inside the $275m fraud call-centr...
# 16         Urbashi Mitra - Connected Data London 2024
#
#                                               content  \
# 45  Connected data analytics platform. Explore how...
# 38  Recent Posts Most Used Categories  Monitoring ...
# 18  Sign up Sign in Sign up Sign in RAG on FHIR wi...
# 29  Suggested searches Suggested searches Scam Emp...
# 16  Have you purchased yours? Buy Your All-Access ...
#
#                     category           keyword  \
# 45  organized crime analysis  graph technology
# 38             uncategorized              none
# 18           healthcare data              FHIR
# 29  organized crime analysis       Scam Empire
# 16             uncategorized              none
#
#                                  category_explanation  \
# 45  The article discusses the use of graph technol...
# 38                         Failed to process content.
# 18  The article discusses the use of Fast Healthca...
# 29  The article discusses an investigation into a ...
# 16                         Failed to process content.
#
#                                   keyword_explanation
# 45  Graph technology is the core technology used t...
# 38                       Failed to extract a keyword.
# 18  FHIR is the primary focus and central concept ...
# 29  Scam Empire is the name of the investigation a...
# 16                       Failed to extract a keyword.

# %%
# SECTION 2: KÙZU DATABASE AND VISUALIZATION
# ----------------------------------------
# This section initializes the Kùzu database, populates it with data from links_with_metadata.csv,
# queries for interconnections, and visualizes the graph with yFiles.

# %%
# Cell 4: Initialize Kùzu database
import kuzu
import os
import shutil

db_path = os.path.join("..", "db", "graph_db")

# Delete existing database to ensure fresh state
if os.path.exists(db_path):
    shutil.rmtree(db_path)
    print(f"Deleted existing database at {db_path}")

try:
    os.makedirs(db_path, exist_ok=True)
    print(f"Ensured database directory at {db_path}")

    db = kuzu.Database(db_path)
    conn = kuzu.Connection(db)

    try:
        # Create schema
        conn.execute("CREATE NODE TABLE Link(url STRING, category STRING, title STRING, keyword STRING, category_explanation STRING, keyword_explanation STRING, PRIMARY KEY(url))")
        conn.execute("CREATE NODE TABLE Category(name STRING, PRIMARY KEY(name))")
        conn.execute("CREATE NODE TABLE Keyword(name STRING, PRIMARY KEY(name))")
        conn.execute("CREATE REL TABLE BELONGS_TO(FROM Link TO Category)")
        conn.execute("CREATE REL TABLE HAS_KEYWORD(FROM Link TO Keyword)")
        print("Database schema created successfully.")

        # Verify schema
        result = conn.execute("CALL show_tables() RETURN name")
        tables = []
        while result.has_next():
            row = result.get_next()
            tables.append(row[0])
        if "Link" not in tables:
            raise ValueError("Link table not found in schema after creation.")
        print("Schema verified: Link table exists.")

    except Exception as e:
        print(f"Error creating schema: {str(e)}")
        raise

finally:
    if 'conn' in locals():
        conn.close()
    if 'db' in locals():
        del db
# Out:
# Deleted existing database at ..\db\graph_db
# Ensured database directory at ..\db\graph_db
# Database schema created successfully.
# Schema verified: Link table exists.

# %%
# Cell 5: Populate Kùzu database with links, categories, and keywords
import kuzu
import pandas as pd
import os

db_path = os.path.join("..", "db", "graph_db")
csv_path = "links_with_metadata.csv"

try:
    # Validate CSV
    if not os.path.exists(csv_path):
        raise FileNotFoundError(f"{csv_path} not found")
    links_df = pd.read_csv(csv_path)
    required_columns = ['url', 'category', 'title', 'keyword', 'category_explanation', 'keyword_explanation']
    if not all(col in links_df.columns for col in required_columns):
        raise ValueError(f"CSV missing required columns: {required_columns}")

    # Initialize database and connection
    db = kuzu.Database(db_path)
    conn = kuzu.Connection(db)

    # Verify schema
    result = conn.execute("CALL show_tables() RETURN name")
    tables = [row[0] for row in [conn.execute("CALL show_tables() RETURN name").get_next() for _ in range(conn.execute("CALL show_tables() RETURN name").get_num_tuples())]]
    if "Link" not in tables:
        raise ValueError("Link table not found. Run Cell 4 to recreate the database.")

    # Batch insert categories
    for category in links_df['category'].unique():
        if pd.notna(category) and category != "uncategorized":
            category = category.replace("'", "\\'")
            conn.execute(f"MERGE (c:Category {{name: '{category}'}})")

    # Batch insert keywords
    for keyword in links_df['keyword'].unique():
        if pd.notna(keyword) and keyword != "none":
            keyword = keyword.replace("'", "\\'")
            conn.execute(f"MERGE (k:Keyword {{name: '{keyword}'}})")

    # Insert links and relationships
    for _, row in links_df.iterrows():
        url = row['url'].replace("'", "\\'")
        category = row['category'].replace("'", "\\'") if pd.notna(row['category']) else "uncategorized"
        title = row['title'].replace("'", "\\'") if pd.notna(row['title']) else ""
        keyword = row['keyword'].replace("'", "\\'") if pd.notna(row['keyword']) else "none"
        category_explanation = row['category_explanation'].replace("'", "\\'") if pd.notna(row['category_explanation']) else ""
        keyword_explanation = row['keyword_explanation'].replace("'", "\\'") if pd.notna(row['keyword_explanation']) else ""
        
        conn.execute(f"""
            MERGE (l:Link {{url: '{url}'}})
            SET l.category = '{category}',
                l.title = '{title}',
                l.keyword = '{keyword}',
                l.category_explanation = '{category_explanation}',
                l.keyword_explanation = '{keyword_explanation}'
        """)
        
        if pd.notna(row['category']) and row['category'] != "uncategorized":
            conn.execute(f"""
                MATCH (l:Link {{url: '{url}'}}), (c:Category {{name: '{category}'}})
                MERGE (l)-[:BELONGS_TO]->(c)
            """)

        if keyword != "none":
            conn.execute(f"""
                MATCH (l:Link {{url: '{url}'}}), (k:Keyword {{name: '{keyword}'}})
                MERGE (l)-[:HAS_KEYWORD]->(k)
            """)

    print("Kùzu database populated successfully.")
    result = conn.execute("MATCH (l:Link) WHERE l.category = 'uncategorized' RETURN COUNT(l)")
    print(f"Uncategorized nodes: {result.get_next()[0]}")

finally:
    if 'conn' in locals():
        conn.close()
    if 'db' in locals():
        del db
# Out:
# Kùzu database populated successfully.
# Uncategorized nodes: 10

# %%
# Cell 6: Query Kùzu for interconnections between categories
import kuzu
import pandas as pd
import os

db_path = os.path.join("..", "db", "graph_db")

try:
    db = kuzu.Database(db_path)
    conn = kuzu.Connection(db)

    # Diagnostic queries
    result = conn.execute("MATCH (l:Link) RETURN COUNT(l)")
    link_count = result.get_next()[0]
    print(f"Total Link nodes: {link_count}")
    if link_count == 0:
        raise ValueError("No Link nodes found. Run Cell 5.")

    result = conn.execute("MATCH (l:Link)-[:HAS_KEYWORD]->(k:Keyword) RETURN COUNT(l)")
    print(f"Links with keywords: {result.get_next()[0]}")
    result = conn.execute("MATCH (l:Link)-[:BELONGS_TO]->(c:Category) RETURN COUNT(l)")
    print(f"Links with categories: {result.get_next()[0]}")

    # Query interconnections
    results = conn.execute("""
        MATCH (l1:Link)-[:HAS_KEYWORD]->(k:Keyword)<-[:HAS_KEYWORD]-(l2:Link),
              (l1)-[:BELONGS_TO]->(c1:Category),
              (l2)-[:BELONGS_TO]->(c2:Category)
        WHERE c1.name <> c2.name AND l1.url < l2.url
        RETURN l1.url, l1.category, l2.url, l2.category, k.name AS shared_keyword
        ORDER BY k.name, l1.category, l2.category
        LIMIT 100
    """)

    interconnections = []
    while results.has_next():
        row = results.get_next()
        interconnections.append({
            "Link1_URL": row[0],
            "Link1_Category": row[1],
            "Link2_URL": row[2],
            "Link2_Category": row[3],
            "Shared_Keyword": row[4]
        })

    interconnections_df = pd.DataFrame(interconnections)
    if not interconnections_df.empty:
        print("Interconnections between categories:")
        print(interconnections_df.to_string(index=False))
    else:
        print("No interconnections found. Verify keywords and categories.")

finally:
    if 'conn' in locals():
        conn.close()
    if 'db' in locals():
        del db
# Out:
# Total Link nodes: 56
# Links with keywords: 46
# Links with categories: 46
# Interconnections between categories:
#                                                                                                                                     Link1_URL     Link1_Category                                                                         Link2_URL       Link2_Category  Shared_Keyword
# https://medium.com/eqtventures/knowledge-graph-s-and-llm-based-ontologies-have-a-very-good-shot-at-unlocking-genai-in-production-1b167533ef63 graph technologies https://www.mongodb.com/blog/post/supercharge-ai-data-management-knowledge-graphs ai and legal systems knowledge graph

# %%
# Cell 7: Clean Kùzu graph and visualize with yFiles
import kuzu
import os
import pandas as pd
try:
    from yfiles_jupyter_graphs import GraphWidget
except ImportError:
    raise ImportError("Install yfiles-jupyter-graphs: pip install yfiles-jupyter-graphs")

db_path = os.path.join("..", "db", "graph_db")

def clean_uncategorized_links(db_path):
    try:
        db = kuzu.Database(db_path)
        conn = kuzu.Connection(db)

        # Save uncategorized links
        result = conn.execute("MATCH (l:Link) WHERE l.category = 'uncategorized' RETURN l.url, l.title")
        uncategorized = []
        while result.has_next():
            row = result.get_next()
            uncategorized.append({"url": row[0], "title": row[1]})
        if uncategorized:
            pd.DataFrame(uncategorized).to_csv("uncategorized_links.csv", index=False)
            print(f"Saved {len(uncategorized)} uncategorized links.")

        # Clean database
        conn.execute("MATCH (l:Link)-[r:HAS_KEYWORD]->(k:Keyword) WHERE l.category = 'uncategorized' DELETE r")
        conn.execute("MATCH (l:Link)-[r:BELONGS_TO]->(c:Category) WHERE l.category = 'uncategorized' DELETE r")
        conn.execute("MATCH (l:Link) WHERE l.category = 'uncategorized' DELETE l")
        conn.execute("MATCH (c:Category) WHERE NOT (c)<-[:BELONGS_TO]-() DELETE c")
        conn.execute("MATCH (k:Keyword) WHERE NOT (k)<-[:HAS_KEYWORD]-() DELETE k")
        print("Uncategorized nodes cleaned.")
        return conn, db

    except Exception as e:
        print(f"Error cleaning database: {str(e)}")
        raise

try:
    conn, db = clean_uncategorized_links(db_path)

    # Validate data
    result = conn.execute("MATCH (l:Link) RETURN COUNT(l)")
    link_count = result.get_next()[0]
    if link_count == 0:
        raise ValueError("No Link nodes found. Run Cell 5.")

    nodes = []
    edges = []

    # Add Link nodes
    result = conn.execute("MATCH (l:Link) RETURN l.url, l.category, l.title LIMIT 50")
    while result.has_next():
        row = result.get_next()
        nodes.append({"id": row[0], "properties": {"type": "Link", "label": row[2] or row[0], "category": row[1]}})

    # Add Category nodes
    result = conn.execute("MATCH (c:Category) RETURN c.name")
    while result.has_next():
        nodes.append({"id": result.get_next()[0], "properties": {"type": "Category", "label": result.get_next()[0]}})

    # Add Keyword nodes
    result = conn.execute("MATCH (k:Keyword) RETURN k.name")
    while result.has_next():
        nodes.append({"id": result.get_next()[0], "properties": {"type": "Keyword", "label": result.get_next()[0]}})

    # Add BELONGS_TO edges
    result = conn.execute("MATCH (l:Link)-[:BELONGS_TO]->(c:Category) RETURN l.url, c.name")
    while result.has_next():
        row = result.get_next()
        edges.append({"start": row[0], "end": row[1], "properties": {"type": "BELONGS_TO"}})

    # Add HAS_KEYWORD edges
    result = conn.execute("MATCH (l:Link)-[:HAS_KEYWORD]->(k:Keyword) RETURN l.url, k.name")
    while result.has_next():
        row = result.get_next()
        edges.append({"start": row[0], "end": row[1], "properties": {"type": "HAS_KEYWORD"}})

    # Visualize
    w = GraphWidget()
    w.nodes = nodes
    w.edges = edges

    def node_mappings(node):
        node_type = node['properties']['type']
        if node_type == "Link":
            return {"color": "#1E90FF", "shape": "rectangle"}
        elif node_type == "Category":
            return {"color": "#32CD32", "shape": "ellipse"}
        elif node_type == "Keyword":
            return {"color": "#FF4500", "shape": "triangle"}
        return {"color": "#808080", "shape": "circle"}

    w.node_mappings = node_mappings

    def edge_mappings(edge):
        edge_type = edge['properties']['type']
        if edge_type == "BELONGS_TO":
            return {"color": "#FFD700"}
        elif edge_type == "HAS_KEYWORD":
            return {"color": "#9932CC"}
        return {"color": "#000000"}

    w.node_label_mapping = lambda node: node['properties']['label']
    w.show()
    print("Graph visualization completed.")

finally:
    if 'conn' in locals():
        conn.close()
    if 'db' in locals():
        del db
# Out:
# Uncategorized nodes cleaned.
# GraphWidget(layout=Layout(height='800px', width='100%'))
# Graph visualization completed.
